# %%
import tensorflow as tf
#from keras.models import load_model

# %%
model = tf.keras.models.load_model('modelfullwithcloth.h5')

# %%
test_dir = r'F:\\GAIT RECOGNITION\\fulldatasetwithcloth\\test'

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

height=240
width=240
batch_size=32


# Test generator
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(test_dir, 
                                                  target_size=(height,width), 
                                                  batch_size=batch_size,
                                                  color_mode='grayscale',
                                                  shuffle = False,
                                                  class_mode='categorical')
# Out:
# Found 4945 images belonging to 124 classes.

# %%
import os

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
test_acc = model.evaluate(test_generator,verbose=1)                  
print(test_acc)
# Out:
# 155/155 [==============================] - 27s 173ms/step - loss: 0.6571 - acc: 0.9104
# [0.6570864319801331, 0.9104145765304565]

# %%
preds = model.predict(test_generator)

# %%
import numpy as np

train_dir = r'F:\\GAIT RECOGNITION\\fulldatasetwithcloth\\train'


# Training generator
train_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(train_dir, 
                                                    target_size=(height,width),
                                                    batch_size=batch_size,
                                                    color_mode='grayscale',
                                                    class_mode='categorical')



predicted_class_indices=np.argmax(preds,axis=1)
print(predicted_class_indices)


labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]
# Out:
# Found 7657 images belonging to 124 classes.
# [  0   0   0 ... 123 123 123]

# %%
import pandas as pd


filenames=test_generator.filenames
print(filenames)
results=pd.DataFrame({"Filename":filenames,"Predictions":predictions})
results.to_csv("results.csv",index=False)
# Out:
# ['001\\001-bg-02-018.png', '001\\001-bg-02-036.png', '001\\001-bg-02-054.png', '001\\001-bg-02-072.png', '001\\001-bg-02-090.png', '001\\001-bg-02-108.png', '001\\001-bg-02-126.png', '001\\001-bg-02-144.png', '001\\001-bg-02-162.png', '001\\001-cl-02-018.png', '001\\001-cl-02-036.png', '001\\001-cl-02-054.png', '001\\001-cl-02-072.png', '001\\001-cl-02-090.png', '001\\001-cl-02-108.png', '001\\001-cl-02-126.png', '001\\001-cl-02-144.png', '001\\001-cl-02-162.png', '001\\001-nm-05-000.png', '001\\001-nm-05-018.png', '001\\001-nm-05-036.png', '001\\001-nm-05-054.png', '001\\001-nm-05-072.png', '001\\001-nm-05-090.png', '001\\001-nm-05-108.png', '001\\001-nm-05-126.png', '001\\001-nm-05-144.png', '001\\001-nm-05-162.png', '001\\001-nm-05-180.png', '001\\001-nm-06-000.png', '001\\001-nm-06-018.png', '001\\001-nm-06-036.png', '001\\001-nm-06-054.png', '001\\001-nm-06-072.png', '001\\001-nm-06-090.png', '001\\001-nm-06-108.png', '001\\001-nm-06-126.png', '001\\001-nm-06-144.png', '001\\001-nm-06-162.png', '001\\001-nm-06-180.png', '002\\002-bg-02-018.png', '002\\002-bg-02-036.png', '002\\002-bg-02-054.png', '002\\002-bg-02-072.png', '002\\002-bg-02-090.png', '002\\002-bg-02-108.png', '002\\002-bg-02-126.png', '002\\002-bg-02-144.png', '002\\002-bg-02-162.png', '002\\002-cl-02-018.png', '002\\002-cl-02-036.png', '002\\002-cl-02-054.png', '002\\002-cl-02-072.png', '002\\002-cl-02-090.png', '002\\002-cl-02-108.png', '002\\002-cl-02-126.png', '002\\002-cl-02-144.png', '002\\002-cl-02-162.png', '002\\002-nm-05-000.png', '002\\002-nm-05-018.png', '002\\002-nm-05-036.png', '002\\002-nm-05-054.png', '002\\002-nm-05-072.png', '002\\002-nm-05-090.png', '002\\002-nm-05-108.png', '002\\002-nm-05-126.png', '002\\002-nm-05-144.png', '002\\002-nm-05-162.png', '002\\002-nm-05-180.png', '002\\002-nm-06-000.png', '002\\002-nm-06-018.png', '002\\002-nm-06-036.png', '002\\002-nm-06-054.png', '002\\002-nm-06-072.png', '002\\002-nm-06-090.png', '002\\002-nm-06-108.png', '002\\002-nm-06-126.png', '002\\002-nm-06-144.png', '002\\002-nm-06-162.png', '002\\002-nm-06-180.png', '003\\003-bg-02-018.png', '003\\003-bg-02-036.png', '003\\003-bg-02-054.png', '003\\003-bg-02-072.png', '003\\003-bg-02-090.png', '003\\003-bg-02-108.png', '003\\003-bg-02-126.png', '003\\003-bg-02-144.png', '003\\003-bg-02-162.png', '003\\003-cl-02-018.png', '003\\003-cl-02-036.png', '003\\003-cl-02-054.png', '003\\003-cl-02-072.png', '003\\003-cl-02-090.png', '003\\003-cl-02-108.png', '003\\003-cl-02-126.png', '003\\003-cl-02-144.png', '003\\003-cl-02-162.png', '003\\003-nm-05-000.png', '003\\003-nm-05-018.png', '003\\003-nm-05-036.png', '003\\003-nm-05-054.png', '003\\003-nm-05-072.png', '003\\003-nm-05-090.png', '003\\003-nm-05-108.png', '003\\003-nm-05-126.png', '003\\003-nm-05-144.png', '003\\003-nm-05-162.png', '003\\003-nm-05-180.png', '003\\003-nm-06-000.png', '003\\003-nm-06-018.png', '003\\003-nm-06-036.png', '003\\003-nm-06-054.png', '003\\003-nm-06-072.png', '003\\003-nm-06-090.png', '003\\003-nm-06-108.png', '003\\003-nm-06-126.png', '003\\003-nm-06-144.png', '003\\003-nm-06-162.png', '003\\003-nm-06-180.png', '004\\004-bg-02-018.png', '004\\004-bg-02-036.png', '004\\004-bg-02-054.png', '004\\004-bg-02-072.png', '004\\004-bg-02-090.png', '004\\004-bg-02-108.png', '004\\004-bg-02-126.png', '004\\004-bg-02-144.png', '004\\004-bg-02-162.png', '004\\004-cl-02-018.png', '004\\004-cl-02-036.png', '004\\004-cl-02-054.png', '004\\004-cl-02-072.png', '004\\004-cl-02-090.png', '004\\004-cl-02-108.png', '004\\004-cl-02-126.png', '004\\004-cl-02-144.png', '004\\004-cl-02-162.png', '004\\004-nm-05-000.png', '004\\004-nm-05-018.png', '004\\004-nm-05-036.png', '004\\004-nm-05-054.png', '004\\004-nm-05-072.png', '004\\004-nm-05-090.png', '004\\004-nm-05-108.png', '004\\004-nm-05-126.png', '004\\004-nm-05-144.png', '004\\004-nm-05-162.png', '004\\004-nm-05-180.png', '004\\004-nm-06-000.png', '004\\004-nm-06-018.png', '004\\004-nm-06-036.png', '004\\004-nm-06-054.png', '004\\004-nm-06-072.p ...

# %%
from PIL import Image
from skimage import transform

def load(filename):
   np_image = Image.open(filename)
   np_image = np.array(np_image).astype('float32')/255
   np_image = transform.resize(np_image, (240, 240, 1))
   np_image = np.expand_dims(np_image, axis=0)
   return np_image


toBePred = load(r'F:\\GAIT RECOGNITION\\fulldatasetwithcloth\\test\\080\\080-nm-06-000.png')

single_pred = model.predict(toBePred) 

#print(single_pred)

predicted_class_indices=np.argmax(single_pred,axis=1)
print(predicted_class_indices)
# Out:
# [79]
